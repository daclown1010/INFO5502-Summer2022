# %% [markdown]
# <a href="https://colab.research.google.com/github/daclown1010/INFO5502-Summer2022/blob/main/FinalLab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
population = pd.read_csv('https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab_assignment_05_census.csv')

# %%
plt.title("Age Distribution of censored people over the 2 years")
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)
sns.scatterplot(data = population, x = 'Age', y = 'People', hue = 'Sex');
